# %%
print("Jupyter is working")
# Out:
# Jupyter is working

# %%
num=5
print(num)
# Out:
# 5

# %%
num=int(input("Enter a number :"))
print(num)
# Out:
# Enter a number : 9
# 9

# %%
num=int(input("Enter a number :"))
if num>0:
    print("Give Number is Positive number")
# Out:
# Enter a number : 6
# Give Number is Positive number

# %%
num=int(input("Enter a number :"))
if num>0:
    print("Give Number is Positive number")
else:
    print("Give Number is negative number")
# Out:
# Enter a number : 55
# Give Number is Positive number

# %%
num=int(input("Enter a number :"))
if num>0:
    print("Give Number is Positive number")
elif num<0:
    print("Give Number is negative number")
else:
    print("Give Number is Zero")
# Out:
# Enter a number : -5
# Give Number is negative number

# %%
num=int(input("Enter a number :"))
if num!=0:
    if num>0:
        print("Give Number is Positive")
    else:
        print("Give Number is Negative")
else:
    print("Give Number is Zero")
# Out:
# Enter a number : 9
# Give Number is Positive

# %%
n=5
for i in range(0,n,1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n=5
for i in range(n+1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
n=5
for i in range(0,n+1,2):
    print(i)
# Out:
# 0
# 2
# 4

# %%
n=5
for i in range(1,n,2):
    print(i)
# Out:
# 1
# 3

# %%
n=5
i=0
while(i<=5):
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
for i in range(5):
    if i==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
i=0
while i<=5:
    if i==3:
        break
    print(i)
    i+=1
# Out:
# 0
# 1
# 2

# %%
i=0                     
while i<=5:
    if i==3:
        i+=1
        continue
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
# 4
# 5

# %%
i=0
while i<=5:
    if i==3:
        break
    print(i)
    i+=1
# Out:
# 0
# 1
# 2
